# %%
print('This is my first time testing Google Colab')
# Out:
# This is my first time testing Google Colab

# %% [markdown]
# # **I can create text That supports markdown**
# I am good with markdown.. Well creating tables give me a hardtime

# %%
print('This is on google servers')
name = 'Joseph Ngigi'
interest = 'Data analysis'
print(name + '; ' + interest)
# Out:
# This is on google servers
# Joseph Ngigi; Data analysis

# %%
# I can use the following
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

print(tf.__version__)
# Out:
# 2.11.0
