# %%
print('This is my first time testing Google Colab')
# Out:
# This is my first time testing Google Colab

# %% [markdown]
# # **I can create text That supports markdown**
# I am good with markdown.. Well creating tables give me a hardtime

# %%
print('This is on google servers')
name = 'Joseph Ngigi'
interest = 'Data analysis'
print(name + '; ' + interest)
# Out:
# This is on google servers
# Joseph Ngigi; Data analysis

# %%
# I can use the following
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

print(tf.__version__)
# Out:
# 2.11.0

# %%
print('Will Wakatime recordthe time that I will spend in the google colab? I am not sure, let me record')
print('Anaconda keeps on opening my windows terminal. I am not sure why. I want to see how Ican record time spent')
print('Haha --- will I c(another interruption)rack this')
print('My laptop is so slow. Using some 4 gigs ram.. The other slot got damaged')
print('this makes me spent so much time on one project. I (another one before chrome hangs for some few mins) sometimes want to give up')
print('I hope I get a new one soon')
print('it is working now.. Let us run this code')
# Out:
# Will Wakatime recordthe time that I will spend in the google colab? I am not sure, let me record
# Anaconda keeps on opening my windows terminal. I am not sure why. I want to see how Ican record time spent
# Haha --- will I c(another interruption)rack this
# My laptop is so slow. Using some 4 gigs ram.. The other slot got damaged
# this makes me spent so much time on one project. I (another one before chrome hangs for some few mins) sometimes want to give up
# I hope I get a new one soon
# it is working now.. Let us run this code
